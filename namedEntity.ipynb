# %%
from pathlib import Path
from datetime import datetime as dt
import pandas as pd

# %%
path="C:/Users/FUJITSU/Desktop/arabic named entity/ANERCorp.xlsx"

# %%
xlsx = pd.ExcelFile(path)

# %%
df=pd.read_excel(xlsx, header=None)

# %%
df
# Out:
#                 0       1    2
# 0       فرانكفورت   B-LOC  NaN
# 1              (د       O  NaN
# 2               ب       O  NaN
# 3              أ)       O  NaN
# 4            أعلن       O  NaN
# 5           اتحاد   B-ORG  NaN
# 6           صناعة   I-ORG  NaN
# 7        السيارات   I-ORG  NaN
# 8              في       O  NaN
# 9         ألمانيا   B-LOC  NaN
# 10            امس       O  NaN
# 11          الاول       O  NaN
# 12             أن       O  NaN
# 13          شركات       O  NaN
# 14          صناعة       O  NaN
# 15       السيارات       O  NaN
# 16             في       O  NaN
# 17        ألمانيا   B-LOC  NaN
# 18          تواجه       O  NaN
# 19           عاما       O  NaN
# 20           صعبا       O  NaN
# 21             في       O  NaN
# 22             ظل       O  NaN
# 23           ركود       O  NaN
# 24          السوق       O  NaN
# 25       الداخلية       O  NaN
# 26      والصادرات       O  NaN
# 27            وهي       O  NaN
# 28           تسعي       O  NaN
# 29            لان       O  NaN
# ...           ...     ...  ...
# 150256       2003       O  NaN
# 150257          ،       O  NaN
# 150258        على       O  NaN
# 150259      جائزة       O  NaN
# 150260       أجمل       O  NaN
# 150261      تصميم       O  NaN
# 150262     لمبنىً       O  NaN
# 150263       برجي       O  NaN
# 150264         في       O  NaN
# 150265     العالم       O  NaN
# 150266          .       O  NaN
# 150267    وللوليد  B-PERS  NaN
# 150268        ابن       O  NaN
# 150269      وابنة       O  NaN
# 150270          ،       O  NaN
# 150271       خالد  B-PERS  NaN
# 150272       وريم  B-PERS  NaN
# 150273          .       O  NaN
# 150274        وقد       O  NaN
# 150275        صدر       O  NaN
# 150276     مؤخراً       O  NaN
# 150277        أول       O  NaN
# 150278       كتاب       O  NaN
# 150279         عن       O  NaN
# 150280     الحياة       O  NaN
# 150281    الشخصية       O  NaN
# 150282     للوليد  B-PERS  NaN
# 150283         بن  I-PERS  NaN
# 150284       طلال  I-PERS  NaN
# 150285          .       O  NaN
#
# [150286 rows x 3 columns]

# %%
df = df.drop(2, 1)

# %%
df = df.rename(columns={0: 'text', 1: 'label'})

# %%
df
# Out:
#              text   label
# 0       فرانكفورت   B-LOC
# 1              (د       O
# 2               ب       O
# 3              أ)       O
# 4            أعلن       O
# 5           اتحاد   B-ORG
# 6           صناعة   I-ORG
# 7        السيارات   I-ORG
# 8              في       O
# 9         ألمانيا   B-LOC
# 10            امس       O
# 11          الاول       O
# 12             أن       O
# 13          شركات       O
# 14          صناعة       O
# 15       السيارات       O
# 16             في       O
# 17        ألمانيا   B-LOC
# 18          تواجه       O
# 19           عاما       O
# 20           صعبا       O
# 21             في       O
# 22             ظل       O
# 23           ركود       O
# 24          السوق       O
# 25       الداخلية       O
# 26      والصادرات       O
# 27            وهي       O
# 28           تسعي       O
# 29            لان       O
# ...           ...     ...
# 150256       2003       O
# 150257          ،       O
# 150258        على       O
# 150259      جائزة       O
# 150260       أجمل       O
# 150261      تصميم       O
# 150262     لمبنىً       O
# 150263       برجي       O
# 150264         في       O
# 150265     العالم       O
# 150266          .       O
# 150267    وللوليد  B-PERS
# 150268        ابن       O
# 150269      وابنة       O
# 150270          ،       O
# 150271       خالد  B-PERS
# 150272       وريم  B-PERS
# 150273          .       O
# 150274        وقد       O
# 150275        صدر       O
# 150276     مؤخراً       O
# 150277        أول       O
# 150278       كتاب       O
# 150279         عن       O
# 150280     الحياة       O
# 150281    الشخصية       O
# 150282     للوليد  B-PERS
# 150283         بن  I-PERS
# 150284       طلال  I-PERS
# 150285          .       O
#
# [150286 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size = 0.2)
train_arr = []
test_arr = []
train_lbl = []
test_lbl = []

# %%
train_arr=train['text'].astype(str)
train_lbl=train['label'].astype(str)
test_arr=test['text'].astype(str)
test_lbl=test['label'].astype(str)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer,TfidfVectorizer

# %%
vectorizer = CountVectorizer()
vectorizer.fit(train_arr)
train_mat = vectorizer.transform(train_arr)

# %%
tfidf = TfidfTransformer()
tfidf.fit(train_mat)
train_tfmat = tfidf.transform(train_mat)

# %%
test_mat = vectorizer.transform(test_arr)
test_tfmat = tfidf.transform(test_mat)

# %%
del df
del test_arr
del train_arr

# %%
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB

# %%
train_tfmat
# Out:
# <120228x28214 sparse matrix of type '<class 'numpy.float64'>'
# 	with 107937 stored elements in Compressed Sparse Row format>

# %%
from sklearn.svm import LinearSVC

# %%
lsvm=LinearSVC()
lsvm.fit(train_tfmat,train_lbl)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
y_pred_lsvm=lsvm.predict(test_tfmat)

# %%
test=['ألمانيا']
test_str = vectorizer.transform(test)
test_tfstr = tfidf.transform(test_str)
test_tfstr.shape
lsvm.predict(test_tfstr.toarray())[0]
# Out:
# 'B-LOC'

# %%
from sklearn.metrics import  accuracy_score
from sklearn import metrics

# %%
print("accuracy:", metrics.accuracy_score(test_lbl, y_pred_lsvm))
# Out:
# accuracy: 0.934792734048

# %%
phrase="شاهد أحمد مباراة فرنسا"
arr=phrase.split()

# %%
arr
# Out:
# ['شاهد', 'أحمد', 'مباراة', 'فرنسا']

# %%
import sys
y=[]
token=[]
for x in arr:
    x=[x]
    test_str = vectorizer.transform(x)
    test_tfstr = tfidf.transform(test_str)
    test_tfstr.shape
    token.append(x)
    y.append(lsvm.predict(test_tfstr.toarray())[0])

# %%
df=pd.DataFrame(list(zip(token,y)),columns=['token','entity_type'])

# %%
df
# Out:
#       token entity_type
# 0    [شاهد]           O
# 1    [أحمد]      B-PERS
# 2  [مباراة]           O
# 3   [فرنسا]       B-LOC
